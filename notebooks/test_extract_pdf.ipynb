# %%
import pypdf as pdf
import requests
from io import BytesIO

# %%
r = requests.get("https://arxiv.org/pdf/2206.13190v1")
# Out:
# '%PDF-1.5\n%�\n118 0 obj\n<< /Filter /FlateDecode /Length 3595 >>\nstream\nx��Z[���\x11~���[%���w�\x18A��q��m��\x00)�䁒�H�%R!�\x1c�����ܥ(��H�>�\\���}��U:����__�����\x17�ުl�\'��rv�0#I�f�-��\x19�\'E�$ejv\x7f�}�������bIy6/�Ϻ>\x1c\x1b��U[.(��� b��OES�u�VT\x1b�P�ڲ�o�\x03��\U000eab96G���b_����\x07��M��\u05fd.��������]�i\x17?�\x7f��Ӏq��\t��e�p����ݻ7�eSt�}�`\t��*O��1\x05��6�`\x1a\x11�_\x02�L̻�R�v�>�t��\'#.��\x1a��Qs�{��j��1\x16)W�r�\\\x0f�z�»U�y�kw�RN�%���Υ�t.E�s��un^vł���a��;��Һ���u�9�;O�Iw�b���[]���c\x15�{���Շ�\x11�5Z�&B\x19�J\x18�"�z\x02��u�\\�t��CQV��T\x15U��\x1b��C\x12���(,��lI�|9��o��O��xև�H����r���Fڂ�P[�\x1ah\x0bެ���\x0fuspLZ��\x01]���)��\x13��Kl�I�1�\x0cΒLʙ�_�4�\x06\x1dP�3vy�.��e�q�Z�\u05fe�t���>w���O\x131\x1bm\x11\x19���h��;\x1a>��Վ���\x12.�[*�����@y��6�\x1e+[��~\x02�˃��boG[\x10�g�x@\x12\x0fzݍ�\x1e��G�,�\x7f\r��Ee�E�S�����r�\x01s2Κ�����\x07�\x12\tgt& ��Y}�\x03�3�\x03S\x18�\x0ch\x1d\x0b`f��9�\x0eƲ���3V\x10\\�C�|�ӌ\x148\x1e�n�`B�\x0f�a�AJ�Om?30,��\x0c\x1b\'\x15\x01I����]��[1\x08g�L\x1c
# ...

# %%
reader = pdf.PdfReader(BytesIO(r.content))

# %%
reader.pages[0].extract_text()
# Out:
# 'An Empirical Study of Personalized Federated\nLearning\nKoji Matsuda, Yuya Sasaki, Chuan Xiao, Makoto Onizuka\nGraduate School of Information Science and Technology\nOsaka University\n{matsuda.koji, sasaki, chuanx, onizuka} @ist.osaka-u.ac.jp\nAbstract\nFederated learning is a distributed machine learning approach in which a single\nserver and multiple clients collaboratively build machine learning models without\nsharing datasets on clients. A challenging issue of federated learning is data\nheterogeneity (i.e., data distributions may differ across clients). To cope with this\nissue, numerous federated learning methods aim at personalized federated learning\nand build optimized models for clients. Whereas existing studies empirically\nevaluated their own methods, the experimental settings (e.g., comparison methods,\ndatasets, and client setting) in these studies differ from each other, and it is unclear\nwhich personalized federate learning method achieves the best performance and\
# ...
